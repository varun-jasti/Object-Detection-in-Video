# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 913.5/913.5 kB 36.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# CLI method

# %%
# !yolo predict model = yolo11m.pt source = "https://wallpapercrafter.com/desktop3/911375-people-car-human-person-taxi-transportation-vehicle.jpg"
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100% 38.8M/38.8M [00:00<00:00, 48.5MB/s]
# Ultralytics 8.3.67 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLO11m summary (fused): 303 layers, 20,091,712 parameters, 0 gradients, 68.0 GFLOPs
#
# ...
# ⚠️ Download failure, retrying 1/3 https://wallpapercrafter.com/desktop3/911375-people-car-human-person-taxi-transportation-vehicle.jpg...
# ############################################################################################# 100.0%
# image 1/1 /content/911375-people-car-human-person-taxi-transportation-vehicle.jpg: 448x640 3 persons, 1 truck, 1 backpack, 3 handbags, 157.5ms
# ...

# %% [markdown]
# Python Method

# %%
from ultralytics import YOLO
model = YOLO("yolo11n-seg.pt")
model.predict(source = "https://domf5oio6qrcr.cloudfront.net/medialibrary/8617/dog-park-petting-dog.jpg" )
# Out:
# ...
# 100%|██████████| 5.90M/5.90M [00:00<00:00, 342MB/s]
# ...
# 100%|██████████| 216k/216k [00:00<00:00, 26.4MB/s]
# image 1/1 /content/dog-park-petting-dog.jpg: 448x640 4 persons, 1 dog, 53.2ms
# Speed: 2.8ms preprocess, 53.2ms inference, 605.3ms postprocess per image at shape (1, 3, 448, 640)
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: ultralytics.engine.results.Masks object
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# !pip install ultralytics
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.67 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 31.2/112.6 GB disk)

# %%
from ultralytics import YOLO
from IPython.display import display, Image

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/YOLO_1/Vehicle Detection
# Out:
# /content/drive/MyDrive/YOLO_1/Vehicle Detection

# %%
{
  "datasets_dir": "/content/drive/MyDrive/YOLO_1/Vehicle Detection"
}
# Out:
# {'datasets_dir': '/content/drive/MyDrive/YOLO_1/Vehicle Detection'}

# %%
# %cd /content/drive/MyDrive/YOLO_1/Vehicle Detection

# !yolo task=detect mode=train model=yolo11m.pt data=data.yaml epochs=20 imgsz=640 plots=True
# Out:
# /content/drive/MyDrive/YOLO_1/Vehicle Detection
# Ultralytics 8.3.67 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !ls runs/detect/train3
# Out:
# args.yaml  weights

# %%
# !yolo task=detect mode=val model=runs/detect/train9/weights/best.pt conf=0.5 data=data.yaml
# Out:
# Ultralytics 8.3.67 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLO11m summary (fused): 303 layers, 20,031,574 parameters, 0 gradients, 67.7 GFLOPs
# val: Scanning /content/drive/MyDrive/YOLO_1/Vehicle Detection/valid/labels.cache... 75 images, 0 backgrounds, 0 corrupt: 100% 75/75 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 5/5 [00:04<00:00,  1.04it/s]
#                    all         75       1458      0.933      0.938       0.96      0.908
#                    car         75       1325       0.94      0.929      0.958      0.878
#                  truck         70        133      0.926      0.947      0.962      0.938
# Speed: 4.9ms preprocess, 25.4ms inference, 0.0ms loss, 8.7ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
import glob
from IPython.display import Image, display
for image_path in glob.glob('/content/drive/MyDrive/YOLO/Dataset/runs/detect/predict*.jpg')[:3]:
  display(Image(filename=image_path, width=600))
  print("\n")

# %%
from ultralytics import YOLO
model = YOLO("best.pt")
model.predict(source = "https://domf5oio6qrcr.cloudfront.net/medialibrary/8617/dog-park-petting-dog.jpg" )

# %%
# !yolo predict task=detect mode=predict model=runs/detect/train9/weights/best.pt source = "/content/56310-479197605.mp4"
# Out:
# Ultralytics 8.3.67 🚀 Python-3.11.11 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLO11m summary (fused): 303 layers, 20,031,574 parameters, 0 gradients, 67.7 GFLOPs
#
# video 1/1 (frame 1/1060) /content/56310-479197605.mp4: 384x640 14 cars, 2 trucks, 66.7ms
# video 1/1 (frame 2/1060) /content/56310-479197605.mp4: 384x640 15 cars, 2 trucks, 24.1ms
# video 1/1 (frame 3/1060) /content/56310-479197605.mp4: 384x640 14 cars, 2 trucks, 24.1ms
# video 1/1 (frame 4/1060) /content/56310-479197605.mp4: 384x640 13 cars, 1 truck, 24.0ms
# video 1/1 (frame 5/1060) /content/56310-479197605.mp4: 384x640 14 cars, 1 truck, 24.0ms
# video 1/1 (frame 6/1060) /content/56310-479197605.mp4: 384x640 14 cars, 1 truck, 24.1ms
# video 1/1 (frame 7/1060) /content/56310-479197605.mp4: 384x640 13 cars, 1 truck, 24.1ms
# video 1/1 (frame 8/1060) /content/56310-479197605.mp4: 384x640 14 cars, 1 truck, 24.0ms
# video 1/1 (frame 9/1060) /content/56310-479197605.mp4: 384x640 16 cars, 1 truck, 24.0ms
# ...
